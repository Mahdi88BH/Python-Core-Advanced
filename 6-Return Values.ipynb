# %% [markdown]
# ## **Some Functions Have Return Values**

# %%
import math

# %%
math.sqrt(42 / math.pi)
# Out:
# 3.656366395715726

# %%
raduis = math.sqrt(42 / math.pi)

raduis
# Out:
# 3.656366395715726

# %%
raduis + math.sqrt(42 / math.pi)
# Out:
# 7.312732791431452

# %% [markdown]
# ## **And Some Have None**

# %%
def repeat(word, n):
    print(word * n)

# %%
res = repeat("Mahdi ", 3)
# Out:
# Mahdi Mahdi Mahdi

# %%
res

# %%
print(res)
# Out:
# None

# %% [markdown]
# A **pure function** is a fundamental concept in functional programming. At its core, a function is considered "pure" if it behaves like a mathematical operation: it only cares about its input and produces an output without affecting the world around it.
#
# - To be pure, a function must satisfy two strict conditions:
# 1. **Determinism (Same Input, Same Output)**
# - Every time you call the function with the same arguments, it must return the exact same result. It cannot rely on any hidden state, external variables, or random data.
#     - **Impure:** A function that uses datetime.now() or random.random().
#     - **Pure:** A function that calculates $x + y$.
# 2. **No Side Effects**
# - A pure function does not modify any state outside of its own scope. It is "read-only" regarding the rest of the program.
#
# - **Side effects include:**
#     - Modifying a global variable.
#     - Changing an attribute of an object passed as an argument.
#     - Printing to the console or writing to a file.
#     - Triggering a network request.

# %%
def repeat_string(word, n):
    return word * n

# %%
res = repeat_string("Mahdi ", 3)

res
# Out:
# 'Mahdi Mahdi Mahdi '

# %% [markdown]
# ## **Return Values and Conditionals**

# %%
def absolute_value(x):
    if x < 0:
        return -x
    else:
        return x

# %%
absolute_value(-6)
# Out:
# 6

# %%
absolute_value(0)
# Out:
# 0

# %%
absolute_value(6)
# Out:
# 6

# %% [markdown]
# ## **Incremental Development**

# %% [markdown]
# **Incremental Development** is a software engineering strategy where you build and test a system in small, manageable pieces rather than trying to write the entire program at once.
#
# > **The philosophy is simple:** "Build a little, test a little." Each small piece you add should result in a functional (even if incomplete) version of the program.
#
# 1. **How the Process Works**
# - Instead of a "Big Bang" approach where you write 500 lines of code and then hit "Run" for the first time, you follow these steps:
#     - **Start with a working foundation:** Write the absolute minimum code to get the program started.
#     - **Add one small feature:** Implement just one new function or logic block.
#     - **Test immediately:** Run the code. If it breaks, you know exactly where the error is (the 5 lines you just added).
#     - **Repeat:** Once the new part works, move on to the next small increment.

# %%
def distance(x1, x2, y1, y2):
    return 0.0

# %%
distance(1, 3, 5, 7)
# Out:
# 0.0

# %%
def distance(x1, x2, y1, y2):
    dx = x2 - x1
    dy = y2 - y1
    return dx, dy

# %%
distance(1, 3, 5, 7)
# Out:
# (2, 2)

# %%
import math

def distance(x1, x2, y1, y2):
    dx = x2 - x1
    dy = y2 - y1
    sum = dx**2 + dy**2
    return math.sqrt(sum)

# %%
distance(1, 3, 5, 7)
# Out:
# 2.8284271247461903

# %% [markdown]
# ## **Boolean Functions**

# %%
def is_divisible(x, y):
    return x % y == 0

# %%
if is_divisible(6, 3):
    print("divisible")
else:
    print("not divisible")
# Out:
# divisible

# %% [markdown]
# ## **Recursion with Return Values**

# %%
def factorial(n):
    if n == 0:
        return 1
    return n * factorial(n-1)

# %%
factorial(6)
# Out:
# 720

# %% [markdown]
# ## **Leap of Faith**

# %% [markdown]
# 1. **The Core Concept: The "Leap of Faith**
# - "The "Leap of Faith" is the act of assuming a function works perfectly without looking at its internal code.
#     - **The Problem:** Following the "flow of execution" (tracing every line) is exhausting. If your code calls a function, which calls another function, which calls another, your brain will quickly run out of "memory."
#     - **The Solution:** Treat functions as Black Boxes. You provide the input, you trust the output, and you ignore the "machinery" inside
# 2. **Why It Works (and why you already do it)**
# - The author points out that you are already a "believer" in the leap of faith:
#     - **Built-in Functions:** When you use math.sqrt(16), you don't go read the source code for how Python calculates square roots. You just trust it returns 4.0.
#     - **Your Own Functions:** Once you have written and tested a function (like is_divisible), you should stop re-reading it. Use it as a reliable tool.
# 3. **Applying It to Recursion**
# - This is where the leap of faith is most important. Recursion is notoriously hard to "trace" because it loops back on itself.
# - To write a recursive function (like Factorial), you shouldn't imagine the computer jumping back and forth. Instead, you ask:
#     - **The Assumption:** "Assuming my function already knows how to solve the problem for $n - 1$..."
#     - **The Logic:** "...how do I use that result to solve for $n$?
#     - **"Example (Factorial):**
#         - If I trust that factorial(4) returns $24$...
#         - Then factorial(5) is simply $5 \times 24$.
#
# | Concept | Description | Why It Matters |
# | :--- | :--- | :--- |
# | **Flow of Execution** | Tracing every single step and jump a program takes line-by-line. | Useful for debugging small snippets but becomes **overwhelming** in large systems. |
# | **The Leap of Faith** | Assuming a function works correctly and returns the right result without looking at its body. | Allows you to focus on the **logic of the current task** rather than internal details. |
# | **Black Box Logic** | Treating functions like `math.sqrt()` or your own tested functions as reliable tools. | You don't need to know *how* a tool is made to know *how* to use it effectively. |
# | **Recursive Trust** | Assuming the $(n-1)$ case of a recursive call is already solved. | Essential for writing recursion; it turns a complex loop into a simple **mathematical definition**. |
# | **Abstraction** | Hiding complexity behind a simple function name. | This is the fundamental building block of **advanced software engineering**. |

# %% [markdown]
# ## **Fibonacci**

# %%
def fibonacci(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fibonacci(n-1) + fibonacci(n-2)

# %%
fibonacci(3)
# Out:
# 2

# %%
fibonacci(2)
# Out:
# 1

# %% [markdown]
# ## **Checking Types**

# %%
isinstance(3, int)
# Out:
# True

# %%
isinstance(3, (int, float)) # equal to isinstance(3, int) isinstance(3, float)
# Out:
# True

# %%
def factorial(n):
    if not isinstance(n, int):
        print("factorial in only for integers")
        return None
    elif n < 0:
        print("factorial only for positive (integers) number")
    elif n == 0:
        return 1
    else:
        return n * factorial(n-1)

# %%
factorial(3)
# Out:
# 6

# %% [markdown]
# ## **Debugging**

# %% [markdown]
# When a function isn't doing its job, the author suggests a "3-Point Inspection" to find the culprit.
#
# ---
#
# - **1. The 3-Point Inspection**
#     - Imagine a function is like a **Juicer**.
#
# | Point of Failure | Concept | The "Juicer" Analogy |
# | :--- | :--- | :--- |
# | **The Arguments** | **Precondition** | You fed the juicer a rock instead of an orange. (The input was bad). |
# | **The Function** | **Postcondition** | You fed it an orange, but the juicer is broken and produces nothing. (The logic is bad). |
# | **The Caller** | **Usage** | The juicer made perfect juice, but you forgot to put a glass under it. (The result was ignored). |
#
#
#
# ---
#
# - **2. Debugging with "Scaffolding"**
#     - **Scaffolding** refers to extra code (like `print` statements) that you build *around* your logic to see what's happening. You remove it once the "building" (your program) is finished.
#
#     - **Step 1: Check the Input (Preconditions)**
#         - If you aren't sure if a function is getting the right data, print it immediately at the top.
# ```python
# def area_of_circle(radius):
#     print(f"DEBUG: Input radius is {radius}") # Check the "Precondition"
#     if radius < 0:
#         print("Error: Radius cannot be negative")
#     # ... logic ...
# ```
#
#     - **Step 2: Check the Output (Postconditions)**
#         - If the input is fine, print the result right before the `return` statement.
# ```python
#     result = 3.14 * (radius ** 2)
#     print(f"DEBUG: Returning {result}") # Check the "Postcondition"
#     return result
# ```
#
# ---
#
# - **3. Visualizing Execution (The Factorial Example)**
#     - The code you provided uses a clever trick: **Dynamic Indentation**. By multiplying a string of spaces by the current value of `n`, the output "steps inward" as the function calls itself (recursion) and "steps outward" as it returns.
#
#
#
# - **Why this is helpful:**
#     - In a recursive function like `factorial(4)`, it can be hard to track how the computer "remembers" where it is. The print output shows you the **Stack**:
# 1.  `factorial 4` starts...
# 2.  It waits for `factorial 3`...
# 3.  Which waits for `factorial 2`...
# 4.  Once `factorial 0` returns `1`, the others can finally finish their math and "return" their results.
#
# ---
#
# - **4. Summary Checklist for Debugging**
#     - If your code crashes or gives a wrong answer, ask these three questions in order:
#         * 1.  **Is the data going IN correct?** (Print arguments at the start).
#         * 2.  **Is the data coming OUT correct?** (Print return values at the end).
#         * 3.  **Is the person who asked for the data using it right?** (Check the line that called the function).
#
# > **A Little Wit:** Debugging is like being the detective in a crime movie where you are also the murderer. Scaffolding just helps you find the clues you left for yourself!

# %% [markdown]
# ## **Glossary**

# %% [markdown]
# - **return value:** The result of a function. If a function call is used as an expression, the return value is the value of the expression.
# - **pure function:** A function that does not display anything or have any other effect, other than returning a return value.
# - **dead code:** Part of a program that can never run, often because it appears after a return statement.
# - **incremental development:** A program development plan intended to avoid debugging by adding and testing only a small amount of code at a time.
# - **scaffolding:** Code that is used during program development but is not part of the final version.
# - **Turing complete:** A language, or subset of a language, is Turing complete if it can perform any computation that can be described by an algorithm.
# - **input validation:** Checking the parameters of a function to make sure they have the correct types and values.

# %% [markdown]
# ## **Exercises**

# %% [markdown]
# ### **Exercise 1**

# %% [markdown]
# - Use **incremental development** to write a function called hypot that returns the length of the hypotenuse of a right triangle given the lengths of the other two legs as arguments.
# - Note that there’s a function in the math module called hypot that does the same thing, but you should not use it for this exercise!
# - Even if you can write the function correctly on the first try, start with a function that always returns 0 and practice making small changes, testing as you go. When you are done, the function should only return a value—it should not display anything.

# %%
import math

def hypot(a, b):
    return math.sqrt(a**2 + b**2)

# %%
hypot(3, 6)
# Out:
# 6.708203932499369

# %% [markdown]
# ### **Exercise 2**

# %% [markdown]
# - Write a boolean function, is_between(x, y, z), that returns True if x < y < z or if z < y < x, and False otherwise.

# %%
def is_between(x, y, z):
    if x<y<z or x>y>z:
        return True
    else:
        return False

# %%
is_between(1, 2, 3)
# Out:
# True

# %%
is_between(2, 1, 3)
# Out:
# False

# %% [markdown]
# ### **Exercise 3**

# %% [markdown]
# The Ackermann function, A m, n , is defined as:
# $$A(m, n) =
# \begin{cases}
# n + 1 & \text{if } m = 0 \\
# A(m-1, 1) & \text{if } m > 0 \text{ and } n = 0 \\
# A(m-1, A(m, n-1)) & \text{if } m > 0 \text{ and } n > 0
# \end{cases}$$
# Write a function named ackermann that evaluates the Ackermann function. What happens if you call ackermann(5, 5)?

# %%
def Ackermann(m,n):
    if m == 0:
        return n+1
    elif m > 0 and n == 0:
        return Ackermann(m-1, 1)
    elif m > 0 and n > 0:
        return Ackermann(m-1, Ackermann(m, n-1))
    else:
        None

# %%
Ackermann(3, 4)
# Out:
# 125

# %% [markdown]
# ### **Exercise 4**

# %% [markdown]
# - The **greatest common divisor (GCD)** of a and b is the largest number that divides both of them with no remainder.
# - One way to find the GCD of two numbers is based on the observation that if r is the remainder when a is divided by b, then gcd a, b = gcd b, r . As a base case, we can use gcd a, 0 = a.
# - Write a function called gcd that takes parameters a and b and returns their greatest common divisor.
